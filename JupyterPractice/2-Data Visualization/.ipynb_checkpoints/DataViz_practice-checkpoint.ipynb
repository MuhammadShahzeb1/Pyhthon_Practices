# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Line and Bar Blots
# ##### here we will practice again for basic plots

# %%
#Line Plot

#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# import dataset
flowers= sns.load_dataset("iris")
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#Line Plot

#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# import dataset
flowers= sns.load_dataset("iris")

# create plot
sns.lineplot(x="sepal_length",y="sepal_width",data=flowers)

plt.show()

# %%
#Line Plot

#import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# import dataset
flowers= sns.load_dataset("iris")

# create plot
sns.catplot(x="sepal_length",y="sepal_width",data=flowers)

plt.show()

# %%
import seaborn as sns
import matplotlib as plt

boat= sns.load_dataset("titanic")
boat
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

boat= sns.load_dataset("titanic")

sns.barplot(x="sex",y="age", data=boat , color="orange"  , saturation=10)
plt.title("Number of males and females and thier ages in titanic")

plt.show()

# %% [markdown]
# ###### will have to practice a lot for all the types of graphs

# %%
import seaborn as sns
import matplotlib.pyplot as plt

boat= sns.load_dataset("titanic")

sns.barplot(x="age",y="sex", data=boat , color="orange"  , saturation=10)
plt.title("Number of males and females and thier ages in titanic")
# to convert it into horizental we will change the values of x and y 
plt.show()

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",
             data=fmri)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="white")
boat= sns.load_dataset("titanic")

g=sns.jointGrid(data="boat", x="sex", y="age", space=0)
g.plot_joint(sns.kdeplot,fill=True, clip=((2200, 6800), (10, 25)),thresh=0, levels=100, cmap="fare")
g.plot_marginals(sns.histplot, color="#03051A", alpha=1, bins=25)
# sns.barplot(x="age",y="sex", data=boat , color="orange"  , saturation=10)
plt.title("Number of males and females and thier ages in titanic")
# to convert it into horizental we will change the values of x and y 
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-9fe44af4ffc5> in <module>
#       4 boat= sns.load_dataset("titanic")
#       5
# ----> 6 g=sns.jointGrid(data="boat", x="sex", y="age", space=0)
#       7 g.plot_joint(sns.kdeplot,fill=True, clip=((2200, 6800), (10, 25)),thresh=0, levels=100, cmap="fare")
#       8 g.plot_marginals(sns.histplot, color="#03051A", alpha=1, bins=25)
#
# AttributeError: module 'seaborn' has no attribute 'jointGrid'

# %% [markdown]
# ### Box plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

boat= sns.load_dataset("titanic")

sns.boxplot(x="sex",y="age", data=boat  , saturation=10)# In[ ]:
plt.title("Number of males and females and thier ages in titanic")
# to convert it into horizental we will change the values of x and y 
plt.show()

# %%
import seaborn
seaborn.set(style="whitegrid")
tip=seaborn.load_dataset("tips")
tip

seaborn.boxplot(x='day',y='tip', data=tip, saturation=9,color="red")
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
import seaborn as sns
import pandas as pd
import numpy as np


sns.set(style="whitegrid")
tip=sns.load_dataset("tips")
tip.describe()

# sns.boxplot(x='day',y='tip', data=tip, saturation=9,color="red")
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
import seaborn
seaborn.set(style="whitegrid")
tip=seaborn.load_dataset("tips")


seaborn.boxplot(x=tip['total_bill'], color="#803828")  # using index and slicing for specific valueb
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
# explore more and more options in data visualizaitons and also try to work on different entities

# %%
import seaborn
seaborn.set(style="whitegrid")
tip=seaborn.load_dataset("tips")
tip

seaborn.boxplot(x='day',y='tip', data=tip, saturation=9,color="red")
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

boat=sns.load_dataset("titanic")
boat.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.boxplot(x="sex",y="fare",data=boat)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='fare'>

# %%
sns.boxplot(x="survived",y="age",data=boat)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
# sns.boxplot(x="sex",y="fare",data=boat)# In[ ]:
# the central line in box shows median so here we will see how to add mean


# the traingle sign showing mean in the table

# %%
# now to add some more sign in box plot like adding a sign of our choice in  mean
import matplotlib.pyplot as plt
sns.boxplot(x="survived",y="age", 
            showmeans=True, 
            meanprops={"marker":"*","markersize":"10","markeredgecolor":"yellow",},
            data=boat)

# now to add labels on x axis and y axis
plt.title("How many survied", size=16,weight="bold"),
#plt.xlabel("How many survied")
#plt.ylabel("what was the age")
# currently facing an issue in lebeling of coordinates
plt.show()

# %% [markdown]
# ### " Data Visualization is one of the most important concept of Datascience so they need to be mastered and practiced alot"

# %% [markdown]
# ### Other Important plots

# %%
# Line plot with multifacets
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

dots=sns.load_dataset("dots")
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
# Line plot with multifacets
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

dots=sns.load_dataset("dots")
# dots.head()

sns.set_theme(style="ticks")

# defining a color pellete
pellete=sns.color_palette('rocket_r')

sns.relplot(x="time", y="firing_rate", data=dots)

# %%
# Line plot with multifacets
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

dots=sns.load_dataset("dots")
# dots.head()

sns.set_theme(style="ticks")

# defining a color pellete
p=sns.color_palette('rocket_r')

sns.relplot(x="time", y="firing_rate", data=dots,
           hue="coherence",size="choice",col="align",kind="line",
           size_order=(["T1","T2"]),palette=p)

# %%
import seaborn as sns
sns.set_theme(style="ticks",palette='pastel')

tip=seaborn.load_dataset("tips")
sns.boxplot( x="day", y="total_bill",
            hue="smoker",
            data=tip,palette=["m","g"])
sns.despine(offset=10,trim=True)

# %%
# import the graphs and change thier data accordingly for usage
# change the dataset and values accordingly

# %% [markdown]
# ### use some exapmple from seaborn built in library
# #### in next step we will modify data according to our need

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Load the example diamonds dataset
diamonds = sns.load_dataset("diamonds")

# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.scatterplot(x="carat", y="price",
                hue="clarity", size="depth",
                palette="ch:r=-.2,d=.3_r",
                hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=diamonds, ax=ax)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",
             data=fmri)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Load the example tips dataset
tips = sns.load_dataset("tips")

# Draw a nested violinplot and split the violins for easier comparison
sns.violinplot(data=tips, x="day", y="total_bill", hue="smoker",
               split=True, inner="quart", linewidth=1,
               palette={"Yes": "b", "No": ".85"})
sns.despine(left=True)

# %%
import numpy as np
import seaborn as sns
sns.set_theme(style="ticks")

rs = np.random.RandomState(11)
x = rs.gamma(2, size=1000)
y = -.5 * x + rs.normal(size=1000)

sns.jointplot(x=x, y=y, kind="hex", color="#4CB391")

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Load the brain networks dataset, select subset, and collapse the multi-index
df = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)

used_networks = [1, 5, 6, 7, 8, 12, 13, 17]
used_columns = (df.columns
                  .get_level_values("network")
                  .astype(int)
                  .isin(used_networks))
df = df.loc[:, used_columns]

df.columns = df.columns.map("-".join)

# Compute a correlation matrix and convert to long-form
corr_mat = df.corr().stack().reset_index(name="correlation")

# Draw each cell as a scatter point with varying size and color
g = sns.relplot(
    data=corr_mat,
    x="level_0", y="level_1", hue="correlation", size="correlation",
    palette="vlag", hue_norm=(-1, 1), edgecolor=".7",
    height=10, sizes=(50, 250), size_norm=(-.2, .8),
)

# Tweak the figure to finalize
g.set(xlabel="", ylabel="", aspect="equal")
g.despine(left=True, bottom=True)
g.ax.margins(.02)
for label in g.ax.get_xticklabels():
    label.set_rotation(90)
for artist in g.legend.legendHandles:
    artist.set_edgecolor(".7")

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="dark")

# Simulate data from a bivariate Gaussian
n = 10000
mean = [0, 0]
cov = [(2, .4), (.4, .2)]
rng = np.random.RandomState(0)
x, y = rng.multivariate_normal(mean, cov, n).T

# Draw a combo histogram and scatterplot with density contours
f, ax = plt.subplots(figsize=(6, 6))
sns.scatterplot(x=x, y=y, s=5, color=".15")
sns.histplot(x=x, y=y, bins=50, pthresh=.1, cmap="mako")
sns.kdeplot(x=x, y=y, levels=5, color="w", linewidths=1)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.set_theme(style="white")

df = sns.load_dataset("penguins")

g = sns.JointGrid(data=df, x="body_mass_g", y="bill_depth_mm", space=0)
g.plot_joint(sns.kdeplot,
             fill=True, clip=((2200, 6800), (10, 25)),
             thresh=0, levels=100, cmap="rocket")
g.plot_marginals(sns.histplot, color="#03051A", alpha=1, bins=25)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")

rs = np.random.RandomState(365)
values = rs.randn(365, 4).cumsum(axis=0)
dates = pd.date_range("1 1 2016", periods=365, freq="D")
data = pd.DataFrame(values, dates, columns=["A", "B", "C", "D"])
data = data.rolling(7).mean()

sns.lineplot(data=data, palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### practicing of built in graph in our data

# %%
import seaborn as sns
tip=sns.load_dataset("tips")
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import numpy as np
import seaborn as sns
sns.set_theme(style="ticks")
tip=sns.load_dataset("tips")

# rs = np.random.RandomState(11)
# x = rs.gamma(2, size=1000)
# y = -.5 * x + rs.normal(size=1000)

sns.jointplot(x="total_bill", y="tip", kind="hex", color="#4CB391", data=tip)

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Load the example tips dataset
tips = sns.load_dataset("tips")

# Draw a nested violinplot and split the violins for easier comparison
sns.violinplot(data=tips, x="day", y="total_bill", hue="smoker",
               split=True, inner="quart", linewidth=1,
               palette={"Yes": "b", "No": ".85"})
sns.despine(left=True)

# %% [markdown]
# ##### practice for basic plots are completed
# #####  next step is to practice on pyplots for interacting plots
